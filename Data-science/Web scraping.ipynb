# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://images.unsplash.com/photo-1517244649640-fcacab5ce213?ixlib=rb-1.2.1&auto=format&fit=crop&w=358&q=80"

# %%
req = requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
data = req.content

# %%
file = open('C:/Users/Ajay/Desktop/myimg.jpg','wb')

# %%
file.write(data)
file.close()

# %%
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}

# %%
df = pd.read_html('http://www.shop.efqm.org/recognition-database/')[0]

# %%
df
# Out:
#                                          Organisation  \
# 0                                  LernZeitRäume e.V.
# 1      APD Ambulante Pflegedienste Gelsenkirchen GmbH
# 2                            University of Winchester
# 3                                            PostMail
# 4                                      Metsä Fibre Oy
# 5                                      Wheatley Group
# 6   Shandong Lingong Construction Machinery Co. Lt...
# 7                                       Dubai Customs
# 8   Bosch Security Systems-Sistemas de Segurança, ...
# 9                     BMW Brilliance Automotive - BBT
# 10                                     GC EUROPE N.V.
# 11                                   Sunneziel Meggen
# 12                                         Merseyrail
# 13                         Regionalspital Emmental AG
# 14                    Univerzita Palackého v Olomouci
# 15            Základní škola, Praha 13, Mohylova 1963
# ...

# %%
df_list = []
headers = {'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.143 Safari/537.36'}
url = "http://www.shop.efqm.org/recognition-database-page{}/"
for var in range(1,15):
    req = requests.get(url.format(var),headers=headers)
    soup = BeautifulSoup(req.content,'lxml')
    table = soup.find_all('table')[0]
    df = pd.read_html(str(table))
    df_list.extend(df)

# %%
len(df_list)
# Out:
# 14

# %%
d = df_list[0]

# %%
type(df_list)
# Out:
# list

# %%
for var in df_list[1:]:
    d = d.append(var,ignore_index=True)

# %%
len(d)
# Out:
# 420

# %%
d
# Out:
#                                           Organisation  \
# 0                                   LernZeitRäume e.V.
# 1       APD Ambulante Pflegedienste Gelsenkirchen GmbH
# 2                             University of Winchester
# 3                                             PostMail
# 4                                       Metsä Fibre Oy
# 5                                       Wheatley Group
# 6    Shandong Lingong Construction Machinery Co. Lt...
# 7                                        Dubai Customs
# 8    Bosch Security Systems-Sistemas de Segurança, ...
# 9                      BMW Brilliance Automotive - BBT
# 10                                      GC EUROPE N.V.
# 11                                    Sunneziel Meggen
# 12                                          Merseyrail
# 13                          Regionalspital Emmental AG
# 14                     Univerzita Palackého v Olomouci
# 15             Základní škola, Praha 13, Mohylova 1963
# ...

# %%
from tabulate import tabulate

# %%
print(tabulate(d,tablefmt='psql',headers='keys'))
# Out:
# +-----+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+----------------------+--------------------------------------------+----------------+
# |     | Organisation                                                                                                                                          | Category                           | Country              | Sector                                     | Date awarded   |
# |-----+-------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------+----------------------+--------------------------------------------+----------------|
# ...
